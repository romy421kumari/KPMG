# %%
import pandas as pd
import numpy as np
import datetime
from matplotlib.ticker import FuncFormatter
import matplotlib.pyplot as plt
import warnings
import math as ma
warnings.filterwarnings("ignore")

# %%
df = pd.read_excel('KPMG_VI_New_raw_data_update_final.xlsx', sheetname="NewCustomerList")
df
# Out:
#      Note: The data and information in this document is reflective of a hypothetical situation and client. This document is to be used for KPMG Virtual Internship purposes only.   \
# 0                                            first_name
# 1                                               Chickie
# 2                                                 Morly
# 3                                               Ardelis
# 4                                                Lucine
# 5                                               Melinda
# 6                                                 Druci
# 7                                              Rutledge
# 8                                                Nancie
# 9                                                  Duff
# 10                                              Barthel
# 11                                             Rockwell
# 12                                              Wheeler
# 13                                                 Olag
# ...

# %%
df.rename(columns={"Note: The data and information in this document is reflective of a hypothetical situation and client. This document is to be used for KPMG Virtual Internship purposes only. ":"fname"}, inplace = True)
df.rename(columns={"Unnamed: 1":"lname",
                   "Unnamed: 2":"gender",
                   "Unnamed: 3":"3y_bike_purchases",
                   "Unnamed: 4":"DOB",
                   "Unnamed: 5":"JT",
                   "Unnamed: 6":"Category"}, inplace = True)
df.rename(columns={"Unnamed: 7":"wealth_segement",
                   "Unnamed: 8":"D_Indicator",
                   "Unnamed: 9":"owns_car",
                   "Unnamed: 10":"tencure",
                   "Unnamed: 11":"address",
                   "Unnamed: 12":"postcode"}, inplace = True)
df.rename(columns={"Unnamed: 13":"state",
                   "Unnamed: 14":"country",
                   "Unnamed: 15":"prop_val",
                   "Unnamed: 21":"rank",
                   "Unnamed: 22":"value"}, inplace = True)
df=df.iloc[1:]
df
# Out:
#           fname         lname  gender 3y_bike_purchases                  DOB  \
# 1       Chickie       Brister    Male                86           1957-07-12
# 2         Morly        Genery    Male                69           1970-03-22
# 3       Ardelis     Forrester  Female                10  1974-08-28 00:00:00
# 4        Lucine         Stutt  Female                64           1979-01-28
# 5       Melinda        Hadlee  Female                34           1965-09-21
# 6         Druci       Brandli  Female                39           1951-04-29
# 7      Rutledge         Hallt    Male                23           1976-10-06
# 8        Nancie          Vian  Female                74           1972-12-27
# 9          Duff     Karlowicz    Male                50           1972-04-28
# 10      Barthel        Docket    Male                72           1985-08-02
# 11     Rockwell        Matson    Male                94           1995-01-01
# ...

# %%
df.drop(['Unnamed: 16'],axis=1, inplace=True)
df.drop(['Unnamed: 17'],axis=1, inplace=True)
df.drop(['Unnamed: 18'],axis=1, inplace=True)
df.drop(['Unnamed: 19'],axis=1, inplace=True)
df.drop(['Unnamed: 20'],axis=1, inplace=True)
df.head()
# Out:
#      fname      lname  gender 3y_bike_purchases                  DOB  \
# 1  Chickie    Brister    Male                86           1957-07-12
# 2    Morly     Genery    Male                69           1970-03-22
# 3  Ardelis  Forrester  Female                10  1974-08-28 00:00:00
# 4   Lucine      Stutt  Female                64           1979-01-28
# 5  Melinda     Hadlee  Female                34           1965-09-21
#
#                            JT            Category    wealth_segement  \
# 1             General Manager       Manufacturing      Mass Customer
# 2         Structural Engineer            Property      Mass Customer
# 3      Senior Cost Accountant  Financial Services  Affluent Customer
# 4  Account Representative III       Manufacturing  Affluent Customer
# 5           Financial Analyst  Financial Services  Affluent Customer
#
#   D_Indicator owns_car tencure              address postcode state    country  \
# ...

# %%
df.columns[df.isna().any()].tolist()
# Out:
# ['lname', 'DOB', 'JT', 'Category']

# %%
lnamenan=df['lname'].isna().sum()
Dobnan=df['DOB'].isna().sum()
Jtnan=df['JT'].isna().sum()
categorynan=df['Category'].isna().sum()
print('lname', lnamenan)
print('DOB', Dobnan)
print('JT', Jtnan)
print('Category', categorynan)
# Out:
# lname 29
# DOB 17
# JT 106
# Category 165

# %%
label=['lname','DOB','JT','Category']
y=[29,17,106,165]
x=[1,2,3,4]
plt.bar(x,y)
plt.xticks(x,label)
plt.show()

# %% [markdown]
# # category has most number of NaN values

# %%
#category of services
df['Category'].value_counts()
# Out:
# Financial Services    203
# Manufacturing         199
# Health                152
# Retail                 78
# Property               64
# IT                     51
# Entertainment          37
# Argiculture            26
# Telecommunications     25
# Name: Category, dtype: int64

# %%
df[df['owns_car']=='Yes'].Category.value_counts()
# Out:
# Financial Services    103
# Manufacturing          99
# Health                 73
# Property               36
# Retail                 34
# IT                     26
# Entertainment          16
# Argiculture            13
# Telecommunications      9
# Name: Category, dtype: int64

# %%
e=df[df['owns_car']=='Yes'].Category.value_counts()
e.plot(kind='barh')

# %%
df[df['Category']=="Financial Services"].JT.value_counts()
# Out:
# Cost Accountant                         12
# Financial Analyst                       10
# Senior Cost Accountant                   9
# Paralegal                                9
# Actuary                                  8
# Financial Advisor                        7
# Senior Financial Analyst                 7
# Compensation Analyst                     7
# Junior Executive                         5
# VP Sales                                 4
# Sales Associate                          4
# Senior Sales Associate                   4
# Business Systems Development Analyst     3
# VP Accounting                            3
# Structural Analysis Engineer             3
# Senior Quality Engineer                  3
# GIS Technical Architect                  3
# VP Quality Control                       3
# Community Outreach Specialist            2
# Payment Adjustment Coordinator           2
# Software Consultant                      2
# Staff Scientist                          2
# ...

# %%
b=df[df['Category']=="Financial Services"].JT.value_counts()
b.plot(kind='barh',figsize=(170,150))

# %%
b=df[df['Category']=="Manufacturing"].JT.value_counts()
b.plot(kind='barh',figsize=(170,150))

# %%
# job inside manufacturing category
df[df['Category']=="Manufacturing"].JT.value_counts()
# Out:
# Chemical Engineer                 10
# Civil Engineer                     9
# Nuclear Power Engineer             7
# Geological Engineer                7
# Electrical Engineer                5
# General Manager                    5
# Environmental Tech                 4
# Associate Professor                4
# Marketing Manager                  3
# Account Coordinator                3
# Account Executive                  3
# Professor                          3
# Help Desk Operator                 3
# Structural Engineer                3
# VP Product Management              3
# Technical Writer                   3
# Junior Executive                   3
# Senior Editor                      2
# Internal Auditor                   2
# Desktop Support Technician         2
# Automation Specialist III          2
# Engineer IV                        2
# Geologist IV                       2
# Marketing Assistant                2
# Payment Adjustment Coordinator     2
# ...

# %%
#relation between gender and bike purchases
df[['gender','3y_bike_purchases']]
# Out:
#       gender 3y_bike_purchases
# 1       Male                86
# 2       Male                69
# 3     Female                10
# 4     Female                64
# 5     Female                34
# 6     Female                39
# 7       Male                23
# 8     Female                74
# 9       Male                50
# 10      Male                72
# 11      Male                94
# 12      Male                48
# 13      Male                60
# 14    Female                38
# 15    Female                32
# 16      Male                88
# 17    Female                61
# 18    Female                83
# 19    Female                65
# 20    Female                 2
# 21      Male                11
# 22      Male                44
# 23      Male                26
# 24    Female                 5
# 25    Female                78
# 26      Male                11
# 27    Female                19
# 28    Female                71
# 29    Female                84
# ...
